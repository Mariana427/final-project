# %%
import pandas as pd
from wordcloud import WordCloud
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
df2 = pd.read_csv('train.csv')

# %%
df2["text"] = df2["text"].astype(str)

# %%
new_0 = df2[df2["label"] == 0]

# %%
new_1 = df2[df2["label"] == 1]

# %%
lst_0 = new_0["text"].tolist()
lst_0 = str(lst_0)

# %%
lst_1 = new_1["text"].tolist()
lst_1 = str(lst_1)

# %%
lst_t = df2["text"].tolist()
lst_t = str(lst_t)

# %%
import nltk 
import re 
import numpy as np 
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mari_\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
dataset = nltk.sent_tokenize(lst_0) 
for i in range(len(dataset)): 
    dataset[i] = dataset[i].lower() 
    dataset[i] = re.sub(r'\W', ' ', dataset[i]) 
    dataset[i] = re.sub(r'\s+', ' ', dataset[i])

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mari_\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
word2count = {} 
for data in dataset: 
  
    stop_words = set(stopwords.words('english')) 
    words = nltk.word_tokenize(data) 
    words = [w for w in words if not w in stop_words]

    for word in words: 
        if word not in word2count.keys(): 
            word2count[word] = 1
        else: 
            word2count[word] += 1

# %%
import heapq 
freq_words_0= heapq.nlargest(5000, word2count, key=word2count.get)

# %%
freq_words_0[0:20]
# Out:
# ['said',
#  'mr',
#  'trump',
#  'would',
#  'one',
#  'people',
#  'new',
#  'president',
#  'like',
#  'also',
#  'ms',
#  'could',
#  'time',
#  'state',
#  'two',
#  'years',
#  'many',
#  'states',
#  'first',
#  'last']

# %%
dataset = nltk.sent_tokenize(lst_1) 
for i in range(len(dataset)): 
    dataset[i] = dataset[i].lower() 
    dataset[i] = re.sub(r'\W', ' ', dataset[i]) 
    dataset[i] = re.sub(r'\s+', ' ', dataset[i])

# %%
word2count = {} 
for data in dataset: 
  
    stop_words = set(stopwords.words('english')) 
    words = nltk.word_tokenize(data) 
    words = [w for w in words if not w in stop_words]

    for word in words: 
        if word not in word2count.keys(): 
            word2count[word] = 1
        else: 
            word2count[word] += 1

# %%
freq_words_1= heapq.nlargest(5000, word2count, key=word2count.get)

# %%
freq_words_1[0:20]
# Out:
# ['n',
#  'trump',
#  'clinton',
#  'people',
#  'one',
#  'us',
#  'would',
#  'hillary',
#  'nthe',
#  'said',
#  'new',
#  'like',
#  'also',
#  'time',
#  'world',
#  'state',
#  'even',
#  '2016',
#  'president',
#  'election']

# %%
dataset = nltk.sent_tokenize(lst_t) 
for i in range(len(dataset)): 
    dataset[i] = dataset[i].lower() 
    dataset[i] = re.sub(r'\W', ' ', dataset[i]) 
    dataset[i] = re.sub(r'\s+', ' ', dataset[i])

# %%
word2count = {} 
for data in dataset: 
  
    stop_words = set(stopwords.words('english')) 
    words = nltk.word_tokenize(data) 
    words = [w for w in words if not w in stop_words]

    for word in words: 
        if word not in word2count.keys(): 
            word2count[word] = 1
        else: 
            word2count[word] += 1

# %%
freq_words_t= heapq.nlargest(5000, word2count, key=word2count.get)

# %%
freq_words_t
# Out:
# ['said',
#  'mr',
#  'trump',
#  'one',
#  'would',
#  'people',
#  'new',
#  'clinton',
#  'like',
#  'also',
#  'president',
#  'n',
#  'time',
#  'state',
#  'us',
#  'could',
#  'many',
#  'even',
#  'years',
#  'states',
#  'two',
#  'first',
#  'government',
#  'american',
#  'world',
#  'year',
#  'united',
#  'last',
#  'news',
#  'hillary',
#  'obama',
#  'get',
#  'may',
#  'campaign',
#  'country',
#  'election',
#  'ms',
#  'going',
#  'make',
#  'way',
#  'made',
#  'house',
#  'u',
#  'nthe',
#  'know',
#  'back',
#  'media',
#  'much',
#  'white',
#  'think',
#  'day',
#  'political',
#  'war',
#  'say',
#  '2016',
#  'see',
#  'well',
#  'national',
#  'still',
#  'told',
#  'russia',
#  'public',
#  'since',
#  'take',
#  'work',
#  'right',
#  'want',
#  'police',
#  'donald',
#  'times',
#  'percent',
#  'law',
#  'another',
#  'party',
#  '000',
#  'go',
#  'according',
#  'including',
#  'america',
#  'former',
#  'called',
#  'city',
#  '1',
#  'around',
# ...

# %%
wordcloud = WordCloud().generate(str(freq_words_t))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
