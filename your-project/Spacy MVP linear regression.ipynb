# %%
import spacy
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv("train.csv")

# %%
df["text"] = df["text"].astype(str)

# %%
text = df.drop(["title", "id"], axis = 1)

# %%
import string
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English 

# Create our list of punctuation marks
punctuations = string.punctuation

# %%
# Create our list of stopwords
nlp = English()
stop_words = spacy.lang.en.stop_words.STOP_WORDS

# Load English tokenizer, tagger, parser, NER and word vectors
parser = English()

# Creating our tokenizer function
def spacy_tokenizer(sentence):
    # Creating our token object, which is used to create documents with linguistic annotations.
    mytokens = parser(sentence)

    # Lemmatizing each token and converting each token into lowercase
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]

    # Removing stop words
    mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]

    # return preprocessed list of tokens
    return mytokens

# %%
# Custom transformer using spaCy
class predictors(TransformerMixin):
    def transform(self, X, **transform_params):
        # Cleaning Text
        return [clean_text(text) for text in X]

    def fit(self, X, y=None, **fit_params):
        return self

    def get_params(self, deep=True):
        return {}

# Basic function to clean the text
def clean_text(text):
    # Removing spaces and converting text into lowercase
    return text.strip().lower()

# %%
bow_vector = CountVectorizer(tokenizer = spacy_tokenizer, ngram_range=(1,1))

# %%
tfidf_vector = TfidfVectorizer(tokenizer = spacy_tokenizer)

# %%
from sklearn.model_selection import train_test_split

X = text["text"] # the features we want to analyze
ylabels = text['label'] # the labels, or answers, we want to test against

X_train, X_test, y_train, y_test = train_test_split(X, ylabels, test_size=0.3)

# %%
# Logistic Regression Classifier
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()

# Create pipeline using Bag of Words
pipe = Pipeline([("cleaner", predictors()),
                 ('vectorizer', tfidf_vector),
                 ('classifier', classifier)])

# model generation
pipe.fit(X_train,y_train)
# Out:
# C:\Users\mari_\AppData\Local\Continuum\anaconda3\envs\data\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Pipeline(memory=None,
#          steps=[('cleaner', <__main__.predictors object at 0x0000024CF2976A48>),
#                 ('vectorizer',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=1, ngram_range=(1, 1), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop...
#                                  tokenizer=<function spacy_tokenizer at 0x0000024CD66BB5E8>,
#                                  use_idf=True, vocabulary=None)),
#                 ('classifier',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='warn', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='warn', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
from sklearn import metrics
# Predicting with a test dataset
predicted = pipe.predict(X_test)

# Model Accuracy
print("Logistic Regression Accuracy:",metrics.accuracy_score(y_test, predicted))
print("Logistic Regression Precision:",metrics.precision_score(y_test, predicted))
print("Logistic Regression Recall:",metrics.recall_score(y_test, predicted))
# Out:
# Logistic Regression Accuracy: 0.9570512820512821
# Logistic Regression Precision: 0.9515723270440252
# Logistic Regression Recall: 0.9636942675159236

# %%
# Predicting with a test dataset
predicted_train = pipe.predict(X_train)

# Model Accuracy
print("Logistic Regression Accuracy:",metrics.accuracy_score(y_train, predicted_train))
print("Logistic Regression Precision:",metrics.precision_score(y_train, predicted_train))
print("Logistic Regression Recall:",metrics.recall_score(y_train, predicted_train))
# Out:
# Logistic Regression Accuracy: 0.9809752747252747
# Logistic Regression Precision: 0.9802306425041186
# Logistic Regression Recall: 0.9817131857555341

# %%
print("Logistic Regression matrix:",confusion_matrix(y_test, predicted))

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(df["text"][1])
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Ever ADV advmod
# get AUX ROOT
# the DET det
# feeling VERB dobj
# your DET poss
# life NOUN compound
# circles VERB relcl
# the DET det
# roundabout NOUN dobj
# rather ADV advmod
# than SCONJ cc
# heads NOUN pobj
# in ADP prep
# a DET det
# straight ADJ amod
# line NOUN pobj
# toward ADP prep
# the DET det
# intended ADJ amod
# destination NOUN pobj
# ? PUNCT punct
# [ PUNCT punct
# Hillary PROPN compound
# Clinton PROPN nsubj
# remains VERB ROOT
# the DET det
# big ADJ amod
# woman NOUN attr
# on ADP prep
# campus NOUN pobj
# in ADP prep
# leafy PROPN pobj
# , PUNCT punct
# liberal ADJ amod
# Wellesley PROPN conj
# , PUNCT punct
# Massachusetts PROPN appos
# . PUNCT punct
# Everywhere ADV advmod
# else ADV advmod
# votes VERB ROOT
# her PRON dobj
# most ADV advmod
# likely ADJ amod
# to PART aux
# don VERB xcomp
# her DET poss
# inauguration NOUN compound
# dress NOUN dobj
# for ADP prep
# the DET det
# remainder NOUN pobj
# of ADP prep
# her DET poss
# days NOUN pobj
# the DET det
# way NOUN npadvmod
# Miss PROPN compound
# Havisham PROPN nsubj
# forever ADV advmod
# wore VERB relcl
# that DET det
# wedding NOUN compound
# dress NOUN dobj
# . PUNCT punct
#   SPACE
# Speaking VERB advcl
# of ADP prep
# Great PROPN compound
# Expectations PROPN pobj
# , PUNCT punct
# Hillary PROPN compound
# Rodham PROPN nsubj
# overflowed VERB ROOT
# with ADP prep
# them PRON pobj
# 48 NUM nummod
# years NOUN npadvmod
# ago ADV advmod
# when ADV advmod
# she PRON nsubj
# first ADV advmod
# addressed VERB advcl
# a DET det
# Wellesley PROPN compound
# graduating VERB compound
# class NOUN dobj
# . PUNCT punct
# The DET det
# president NOUN nsubj
# of ADP prep
# the DET det
# college NOUN pobj
# informed VERB ROOT
# those DET dobj
# gathered VERB acl
# in ADP prep
# 1969 NUM pobj
# that SCONJ mark
# the DET det
# students NOUN nsubj
# needed VERB ccomp
# “ PUNCT punct
# no DET det
# debate NOUN dobj
# so ADV advmod
# far ADV advmod
# as SCONJ mark
# I PRON nsubj
# could VERB aux
# ascertain VERB advcl
# as SCONJ prep
# to ADP prep
# who PRON attr
# their DET poss
# spokesman NOUN nsubj
# was AUX pcomp
# to PART aux
# be AUX xcomp
# ” PUNCT punct
# ( PUNCT punct
# kind ADV advmod
# of ADV ROOT
# the DET det
# like INTJ intj
# the DET det
# Democratic ADJ amod
# primaries NOUN pobj
# in ADP prep
# 2016 NUM pobj
# minus CCONJ prep
# the DET det
#    SPACE
# terms NOUN pobj
# unknown ADJ amod
# then ADV punct
# even ADV advmod
# at ADP prep
# a DET det
# Seven PROPN nummod
# Sisters PROPN compound
# school NOUN pobj
# ) PUNCT punct
# . PUNCT punct
# “ PUNCT punct
# I PRON nsubj
# am AUX ccomp
# very ADV advmod
# glad ADJ acomp
# that SCONJ mark
# Miss PROPN compound
# Adams PROPN nsubj
# made VERB ccomp
# it PRON nsubj
# clear ADJ ccomp
# that SCONJ mark
# what PRON dobj
# I PRON nsubj
# am AUX aux
# speaking VERB csubj
# for ADP prep
# today NOUN pobj
# is AUX advcl
# all DET attr
# of ADP prep
# us PRON pobj
# — PUNCT punct
#   SPACE
# the DET det
# 400 NUM appos
# of ADP prep
# us PRON pobj
# , PUNCT punct
# ” PUNCT punct
# Miss PROPN compound
# Rodham PROPN nsubj
# told VERB ROOT
# her DET poss
# classmates NOUN dobj
# . PUNCT punct
# After ADP prep
# appointing VERB pcomp
# herself PRON dative
# Edger PROPN compound
# Bergen PROPN dobj
# to ADP prep
# the DET det
# Charlie PROPN compound
# McCarthys PROPN pobj
# and CCONJ cc
# Mortimer PROPN compound
# Snerds PROPN conj
# in ADP prep
# attendance NOUN pobj
# , PUNCT punct
# the DET det
#     SPACE
# bespectacled PROPN ROOT
# in ADP prep
# granny ADJ amod
# glasses NOUN pobj
# ( PUNCT punct
# awarding VERB advcl
# her DET poss
# matronly ADJ amod
# wisdom NOUN dobj
# — PUNCT punct
#   SPACE
# or CCONJ cc
# at ADP advmod
# least ADJ advmod
# John PROPN compound
# Lennon PROPN compound
# wisdom NOUN conj
# ) PUNCT punct
# took VERB conj
# issue NOUN dobj
# with ADP prep
# the DET det
# previous ADJ amod
# speaker NOUN pobj
# . PUNCT punct
# Despite SCONJ prep
# becoming VERB pcomp
# the DET det
# first ADJ attr
#    SPACE
# to PART aux
# win VERB xcomp
# election NOUN dobj
# to ADP prep
# a DET det
# seat NOUN pobj
# in ADP prep
# the DET det
# U. PROPN compound
# S. PROPN compound
# Senate PROPN pobj
# since SCONJ prep
# Reconstruction PROPN pobj
# , PUNCT punct
# Edward PROPN compound
# Brooke PROPN nsubj
# came VERB ROOT
# in ADP prt
# for ADP prep
# criticism NOUN pobj
# for ADP prep
# calling VERB pcomp
# for ADP prep
# “ PUNCT punct
# empathy NOUN pobj
# ” PUNCT punct
# for ADP prep
# the DET det
# goals NOUN pobj
# of ADP prep
# protestors NOUN pobj
# as SCONJ mark
# he PRON nsubj
# criticized VERB advcl
# tactics NOUN dobj
# . PUNCT punct
# Though SCONJ mark
# Clinton PROPN nsubj
# in ADP prep
# her DET poss
# senior ADJ amod
# thesis NOUN pobj
# on ADP prep
# Saul PROPN compound
# Alinsky PROPN pobj
# lamented VERB ROOT
# “ PUNCT punct
# Black PROPN compound
# Power PROPN compound
# demagogues NOUN nsubj
# ” PUNCT punct
# and CCONJ cc
# “ PUNCT punct
# elitist ADJ amod
# arrogance NOUN conj
# and CCONJ cc
# repressive ADJ amod
# intolerance NOUN conj
# ” PUNCT punct
# within ADP prep
# the DET det
# New PROPN compound
# Left PROPN pobj
# , PUNCT punct
# similar ADJ amod
# words NOUN appos
# coming VERB acl
# out SCONJ prep
# of ADP prep
# a DET det
# Republican PROPN pobj
# necessitated VERB ccomp
# a DET det
# brief ADJ amod
# rebuttal NOUN dobj
# . PUNCT punct
# “ PUNCT punct
# Trust NOUN npadvmod
# , PUNCT punct
# ” PUNCT punct
# Rodham PROPN nsubj
# ironically ADV advmod
# observed VERB ccomp
# in ADP prep
# 1969 NUM pobj
# , PUNCT punct
# “ PUNCT punct
# this DET nsubj
# is AUX ccomp
# one NUM nummod
# word NOUN attr
# that SCONJ mark
# when ADV advmod
# I PRON nsubj
# asked VERB advcl
# the DET det
# class NOUN dobj
# at ADP prep
# our DET poss
# rehearsal NOUN pobj
# what PRON attr
# it PRON nsubj
# was AUX ccomp
# they PRON nsubj
# wanted VERB relcl
# me PRON nsubj
# to PART aux
# say VERB ccomp
# for ADP prep
# them PRON pobj
# , PUNCT punct
# everyone PRON nsubj
# came VERB ROOT
# up ADP prt
# to ADP prep
# me PRON pobj
# and CCONJ cc
# said VERB conj
# ‘ PUNCT punct
# Talk NOUN xcomp
# about ADP prep
# trust NOUN pobj
# , PUNCT punct
# talk VERB conj
# about ADP prep
# the DET det
# lack NOUN pobj
# of ADP prep
# trust NOUN pobj
# both DET advmod
# for ADP prep
# us PRON pobj
# and CCONJ cc
# the DET det
# way NOUN conj
# we PRON nsubj
# feel VERB relcl
# about ADP prep
# others NOUN pobj
# . PUNCT punct
# Talk VERB ROOT
# about ADP prep
# the DET det
# trust NOUN compound
# bust NOUN pobj
# . PUNCT punct
# ’ PUNCT punct
# What PRON dobj
# can VERB aux
# you PRON nsubj
# say VERB ROOT
# about ADP prep
# it PRON pobj
# ? PUNCT punct
# What PRON dobj
# can VERB aux
# you PRON nsubj
# say VERB ROOT
# about ADP prep
# a DET det
# feeling NOUN pobj
# that DET nsubj
# permeates VERB relcl
# a DET det
# generation NOUN dobj
# and CCONJ cc
# that SCONJ nsubj
# perhaps ADV advmod
# is AUX auxpass
# not PART neg
# even ADV advmod
# understood VERB conj
# by ADP agent
# those DET pobj
# who PRON nsubjpass
# are AUX auxpass
# distrusted VERB relcl
# ? PUNCT punct
# ” PUNCT punct
# The DET det
# “ PUNCT punct
# trust NOUN compound
# bust NOUN nsubj
# ” PUNCT punct
# certainly ADV advmod
# busted VERB ROOT
# Clinton PROPN dobj
# ’s PART punct
# 2016 NUM nummod
# plans NOUN dobj
# . PUNCT punct
# She PRON nsubj
# certainly ADV advmod
# did AUX aux
# not PART neg
# even ADV advmod
# understand VERB ROOT
# that SCONJ mark
# people NOUN nsubj
# distrusted VERB ccomp
# her PRON dobj
# . PUNCT punct
# After ADP prep
# Whitewater PROPN pobj
# , PUNCT punct
# Travelgate PROPN appos
# , PUNCT punct
# the DET det
# vast ADJ amod
#    SPACE
# conspiracy NOUN conj
# , PUNCT punct
# Benghazi PROPN conj
# , PUNCT punct
# and CCONJ cc
# the DET det
# missing VERB amod
# emails NOUN conj
# , PUNCT punct
# Clinton PROPN nsubj
# found VERB ROOT
# herself PRON dative
# the DET det
# distrusted VERB amod
# voice NOUN dobj
# on ADP prep
# Friday PROPN pobj
# . PUNCT punct
# There PRON expl
# was AUX ROOT
# a DET det
# load NOUN attr
# of ADP prep
# compromising VERB pcomp
# on ADP prep
# the DET det
# road NOUN pobj
# to ADP prep
# the DET det
# broadening NOUN pobj
# of ADP prep
# her DET poss
# political ADJ amod
# horizons NOUN pobj
# . PUNCT punct
# And CCONJ cc
# distrust VERB npadvmod
# from ADP prep
# the DET det
# American ADJ amod
# people NOUN pobj
# — PUNCT punct
#   SPACE
# Trump PROPN nsubj
# edged VERB ccomp
# her DET poss
# 48 NUM nummod
# percent NOUN dobj
# to ADP prep
# 38 NUM nummod
# percent NOUN pobj
# on ADP prep
# the DET det
# question NOUN pobj
# immediately ADV advmod
# prior ADV advmod
# to ADP prep
# November PROPN pobj
# ’s PART punct
# election NOUN npadvmod
# — PUNCT punct
#   SPACE
# stood VERB ROOT
# as SCONJ prep
# a DET det
# major ADJ amod
# reason NOUN pobj
# for ADP prep
# the DET det
# closing NOUN pobj
# of ADP prep
# those DET det
# horizons NOUN pobj
# . PUNCT punct
# Clinton PROPN nsubj
# described VERB ROOT
# her DET poss
# vanquisher NOUN dobj
# and CCONJ cc
# his DET poss
# supporters NOUN conj
# as SCONJ prep
# embracing VERB pcomp
# a DET det
# “ PUNCT punct
# lie NOUN dobj
# , PUNCT punct
# ” PUNCT punct
# a DET det
# “ PUNCT punct
# con NOUN appos
# , PUNCT punct
# ” PUNCT punct
# “ PUNCT punct
# alternative ADJ amod
# facts NOUN appos
# , PUNCT punct
# ” PUNCT punct
# and CCONJ cc
# “ PUNCT punct
# a DET det
#    SPACE
# assault NOUN conj
# on ADP prep
# truth NOUN pobj
# and CCONJ cc
# reason NOUN conj
# . PUNCT punct
# ” PUNCT punct
# She PRON nsubj
# failed VERB ROOT
# to PART aux
# explain VERB xcomp
# why ADV advmod
# the DET det
# American ADJ amod
# people NOUN nsubj
# chose VERB ccomp
# his DET poss
# lies NOUN dobj
# over ADP prep
# her DET poss
# truth NOUN pobj
# . PUNCT punct
# “ PUNCT punct
# As SCONJ mark
# the DET det
# history NOUN nsubj
# majors NOUN nsubj
# among ADP prep
# you PRON pobj
# here ADV advmod
# today NOUN npadvmod
# know VERB ccomp
# all ADV advmod
# too ADV advmod
# well ADV advmod
# , PUNCT punct
# when ADV advmod
# people NOUN nsubj
# in ADP prep
# power NOUN pobj
# invent VERB advcl
# their DET poss
# own ADJ amod
# facts NOUN dobj
# and CCONJ cc
# attack VERB conj
# those DET dobj
# who PRON nsubj
# question VERB relcl
# them PRON dobj
# , PUNCT punct
# it PRON nsubj
# can VERB aux
# mark VERB ccomp
# the DET det
# beginning NOUN dobj
# of ADP prep
# the DET det
# end NOUN pobj
# of ADP prep
# a DET det
# free ADJ amod
# society NOUN pobj
# , PUNCT punct
# ” PUNCT punct
# she PRON nsubj
# offered VERB ROOT
# . PUNCT punct
# “ PUNCT punct
# That DET nsubj
# is AUX ROOT
# not PART neg
# hyperbole NOUN acomp
# . PUNCT punct
# ” PUNCT punct
# Like SCONJ mark
# so ADV advmod
# many ADJ amod
# people NOUN nsubj
# to PART aux
# emerge VERB advcl
# from ADP prep
# the DET det
# 1960s NOUN pobj
# , PUNCT punct
# Hillary PROPN compound
# Clinton PROPN nsubj
# embarked VERB ROOT
# upon SCONJ prep
# a DET det
# long ADJ amod
# , PUNCT punct
# strange ADJ amod
# trip NOUN pobj
# . PUNCT punct
# From ADP prep
# high ADJ amod
# school NOUN compound
# Goldwater PROPN compound
# Girl PROPN nmod
# and CCONJ cc
# Wellesley PROPN compound
# College PROPN conj
# Republican ADJ amod
# president NOUN pobj
# to ADP prep
# Democratic ADJ amod
# politician NOUN pobj
# , PUNCT punct
# Clinton PROPN nsubj
# drank VERB ROOT
# in ADP prep
# the DET det
# times NOUN pobj
# and CCONJ cc
# the DET det
# place NOUN conj
# that DET nsubj
# gave VERB relcl
# her PRON dative
# a DET det
# degree NOUN dobj
# . PUNCT punct
# More ADV advmod
# significantly ADV advmod
# , PUNCT punct
# she PRON nsubj
# went VERB ROOT
# from ADP prep
# idealist NOUN pobj
# to PART prep
# cynic VERB pobj
# , PUNCT punct
# as SCONJ prep
# a DET det
# comparison NOUN pobj
# of ADP prep
# her DET poss
# two NUM nummod
# Wellesley PROPN compound
# commencement NOUN compound
# addresses NOUN compound
# show VERB pobj
# . PUNCT punct
# Way ADV advmod
# back ADV advmod
# when ADV advmod
# , PUNCT punct
# she PRON nsubj
# lamented VERB ROOT
# that SCONJ mark
# “ PUNCT punct
# for ADP prep
# too ADV advmod
# long ADV pcomp
# our DET poss
# leaders NOUN nsubj
# have AUX aux
# viewed VERB ccomp
# politics NOUN dobj
# as SCONJ prep
# the DET det
# art NOUN pobj
# of ADP prep
# the DET det
# possible ADJ pobj
# , PUNCT punct
# and CCONJ cc
# the DET det
# challenge NOUN nsubj
# now ADV advmod
# is AUX conj
# to PART aux
# practice VERB xcomp
# politics NOUN dobj
# as SCONJ prep
# the DET det
# art NOUN pobj
# of ADP prep
# making VERB pcomp
# what PRON nsubj
# appears VERB ccomp
# to PART aux
# be AUX xcomp
# impossible ADJ advmod
# possible ADJ acomp
# . PUNCT punct
# ” PUNCT punct
# Now ADV advmod
# , PUNCT punct
# as SCONJ prep
# the DET det
# big ADJ amod
# woman NOUN pobj
# on ADP prep
# campus NOUN pobj
# but CCONJ cc
# the DET det
# odd ADJ amod
# woman NOUN conj
# out SCONJ prep
# of ADP prep
# the DET det
# White PROPN compound
# House PROPN pobj
# , PUNCT punct
# she PRON nsubj
# wonders VERB ROOT
# how ADV advmod
# her DET poss
# current ADJ amod
# station NOUN nsubj
# is AUX ccomp
# even ADV advmod
# possible ADJ acomp
# . PUNCT punct
# “ PUNCT punct
# Why ADV advmod
# are AUX ROOT
# n’t PART neg
# I PRON nsubj
# 50 NUM nummod
# points NOUN npadvmod
# ahead ADV advmod
# ? PUNCT punct
# ” PUNCT punct
# she PRON nsubj
# asked VERB ROOT
# in ADP prep
# September PROPN pobj
# . PUNCT punct
# In ADP prep
# May PROPN pobj
# she PRON nsubj
# asks VERB ROOT
# why ADV advmod
# she PRON nsubj
# is AUX ccomp
# n’t PART neg
# president NOUN attr
# . PUNCT punct
# The DET det
# woman NOUN nsubj
# famously ADV advmod
# dubbed VERB ROOT
# a DET det
# “ PUNCT punct
# congenital ADJ amod
# liar NOUN oprd
# ” PUNCT punct
# by ADP prep
# Bill PROPN compound
# Safire PROPN pobj
# concludes VERB conj
# that SCONJ mark
# lies NOUN nsubj
# did AUX ccomp
# her PRON dobj
# in ADP prep
# — PUNCT punct
#   SPACE
# theirs PRON npadvmod
# , PUNCT punct
# mind VERB conj
# you PRON dobj
# , PUNCT punct
# not PART neg
# hers NOUN appos
# . PUNCT punct
# Getting VERB auxpass
# stood VERB ROOT
# up ADP prt
# on ADP prep
# Election PROPN compound
# Day PROPN pobj
# , PUNCT punct
# like SCONJ prep
# finding VERB pcomp
# yourself PRON dobj
# the DET det
# jilted ADJ amod
# bride NOUN dobj
# on ADP prep
# your DET poss
# wedding NOUN compound
# day NOUN pobj
# , PUNCT punct
# inspires NOUN dep
# dangerous ADJ amod
# delusions NOUN dobj
# . PUNCT punct

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Ever ever ADV RB advmod Xxxx True True
# get get AUX VB ROOT xxx True True
# the the DET DT det xxx True True
# feeling feel VERB VBG dobj xxxx True False
# your -PRON- DET PRP$ poss xxxx True True
# life life NOUN NN compound xxxx True False
# circles circle VERB VBZ relcl xxxx True False
# the the DET DT det xxx True True
# roundabout roundabout NOUN NN dobj xxxx True False
# rather rather ADV RB advmod xxxx True True
# than than SCONJ IN cc xxxx True True
# heads head NOUN NNS pobj xxxx True False
# in in ADP IN prep xx True True
# a a DET DT det x True True
# straight straight ADJ JJ amod xxxx True False
# line line NOUN NN pobj xxxx True False
# toward toward ADP IN prep xxxx True True
# the the DET DT det xxx True True
# intended intended ADJ JJ amod xxxx True False
# destination destination NOUN NN pobj xxxx True False
# ? ? PUNCT . punct ? False False
# [ [ PUNCT -LRB- punct [ False False
# Hillary Hillary PROPN NNP compound Xxxxx True False
# Clinton Clinton PROPN NNP nsubj Xxxxx True False
# remains remain VERB VBZ ROOT xxxx True False
# the the DET DT det xxx True True
# big big ADJ JJ amod xxx True False
# woman woman NOUN NN attr xxxx True False
# on on ADP IN prep xx True True
# campus campus NOUN NN pobj xxxx True False
# in in ADP IN prep xx True True
# leafy leafy PROPN NNP pobj xxxx True False
# , , PUNCT , punct , False False
# liberal liberal ADJ JJ amod xxxx True False
# Wellesley Wellesley PROPN NNP conj Xxxxx True False
# , , PUNCT , punct , False False
# Massachusetts Massachusetts PROPN NNP appos Xxxxx True False
# . . PUNCT . punct . False False
# Everywhere everywhere ADV RB advmod Xxxxx True True
# else else ADV RB advmod xxxx True True
# votes vote VERB VBZ ROOT xxxx True False
# her -PRON- PRON PRP dobj xxx True True
# most most ADV RBS advmod xxxx True True
# likely likely ADJ JJ amod xxxx True False
# to to PART TO aux xx True True
# don don VERB VB xcomp xxx True False
# her -PRON- DET PRP$ poss xxx True True
# inauguration inauguration NOUN NN compound xxxx True False
# dress dress NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True True
# the the DET DT det xxx True True
# remainder remainder NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# her -PRON- DET PRP$ poss xxx True True
# days day NOUN NNS pobj xxxx True False
# the the DET DT det xxx True True
# way way NOUN NN npadvmod xxx True False
# Miss Miss PROPN NNP compound Xxxx True False
# Havisham Havisham PROPN NNP nsubj Xxxxx True False
# forever forever ADV RB advmod xxxx True False
# wore wear VERB VBD relcl xxxx True False
# that that DET DT det xxxx True True
# wedding wedding NOUN NN compound xxxx True False
# dress dress NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
#     SPACE _SP    False False
# Speaking speak VERB VBG advcl Xxxxx True False
# of of ADP IN prep xx True True
# Great Great PROPN NNP compound Xxxxx True False
# Expectations Expectations PROPN NNPS pobj Xxxxx True False
# , , PUNCT , punct , False False
# Hillary Hillary PROPN NNP compound Xxxxx True False
# Rodham Rodham PROPN NNP nsubj Xxxxx True False
# overflowed overflow VERB VBD ROOT xxxx True False
# with with ADP IN prep xxxx True True
# them -PRON- PRON PRP pobj xxxx True True
# 48 48 NUM CD nummod dd False False
# years year NOUN NNS npadvmod xxxx True False
# ago ago ADV RB advmod xxx True False
# when when ADV WRB advmod xxxx True True
# she -PRON- PRON PRP nsubj xxx True True
# first first ADV RB advmod xxxx True True
# addressed address VERB VBD advcl xxxx True False
# a a DET DT det x True True
# Wellesley Wellesley PROPN NNP compound Xxxxx True False
# graduating graduate VERB VBG compound xxxx True False
# class class NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True True
# president president NOUN NN nsubj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# college college NOUN NN pobj xxxx True False
# informed inform VERB VBD ROOT xxxx True False
# those those DET DT dobj xxxx True True
# gathered gather VERB VBN acl xxxx True False
# in in ADP IN prep xx True True
# 1969 1969 NUM CD pobj dddd False False
# that that SCONJ IN mark xxxx True True
# the the DET DT det xxx True True
# students student NOUN NNS nsubj xxxx True False
# needed need VERB VBD ccomp xxxx True False
# “ " PUNCT `` punct “ False False
# no no DET DT det xx True True
# debate debate NOUN NN dobj xxxx True False
# so so ADV RB advmod xx True True
# far far ADV RB advmod xxx True False
# as as SCONJ IN mark xx True True
# I -PRON- PRON PRP nsubj X True True
# could could VERB MD aux xxxx True True
# ascertain ascertain VERB VB advcl xxxx True False
# as as SCONJ IN prep xx True True
# to to ADP IN prep xx True True
# who who PRON WP attr xxx True True
# their -PRON- DET PRP$ poss xxxx True True
# spokesman spokesman NOUN NN nsubj xxxx True False
# was be AUX VBD pcomp xxx True True
# to to PART TO aux xx True True
# be be AUX VB xcomp xx True True
# ” " PUNCT '' punct ” False False
# ( ( PUNCT -LRB- punct ( False False
# kind kind ADV RB advmod xxxx True False
# of of ADV RB ROOT xx True True
# the the DET DT det xxx True True
# like like INTJ UH intj xxxx True False
# the the DET DT det xxx True True
# Democratic democratic ADJ JJ amod Xxxxx True False
# primaries primary NOUN NNS pobj xxxx True False
# in in ADP IN prep xx True True
# 2016 2016 NUM CD pobj dddd False False
# minus minus CCONJ CC prep xxxx True False
# the the DET DT det xxx True True
#       SPACE _SP     False False
# terms term NOUN NNS pobj xxxx True False
# unknown unknown ADJ JJ amod xxxx True False
# then then ADV RB punct xxxx True True
# even even ADV RB advmod xxxx True True
# at at ADP IN prep xx True True
# a a DET DT det x True True
# Seven Seven PROPN NNP nummod Xxxxx True False
# Sisters Sisters PROPN NNPS compound Xxxxx True False
# school school NOUN NN pobj xxxx True False
# ) ) PUNCT -RRB- punct ) False False
# . . PUNCT . punct . False False
# “ " PUNCT `` punct “ False False
# I -PRON- PRON PRP nsubj X True True
# am be AUX VBP ccomp xx True True
# very very ADV RB advmod xxxx True True
# glad glad ADJ JJ acomp xxxx True False
# that that SCONJ IN mark xxxx True True
# Miss Miss PROPN NNP compound Xxxx True False
# Adams Adams PROPN NNP nsubj Xxxxx True False
# made make VERB VBD ccomp xxxx True True
# it -PRON- PRON PRP nsubj xx True True
# clear clear ADJ JJ ccomp xxxx True False
# that that SCONJ IN mark xxxx True True
# what what PRON WP dobj xxxx True True
# I -PRON- PRON PRP nsubj X True True
# am be AUX VBP aux xx True True
# speaking speak VERB VBG csubj xxxx True False
# for for ADP IN prep xxx True True
# today today NOUN NN pobj xxxx True False
# is be AUX VBZ advcl xx True True
# all all DET DT attr xxx True True
# of of ADP IN prep xx True True
# us -PRON- PRON PRP pobj xx True True
# — — PUNCT : punct — False False
#     SPACE _SP    False False
# the the DET DT det xxx True True
# 400 400 NUM CD appos ddd False False
# of of ADP IN prep xx True True
# us -PRON- PRON PRP pobj xx True True
# , , PUNCT , punct , False False
# ” " PUNCT '' punct ” False False
# Miss Miss PROPN NNP compound Xxxx True False
# Rodham Rodham PROPN NNP nsubj Xxxxx True False
# told tell VERB VBD ROOT xxxx True False
# her -PRON- DET PRP$ poss xxx True True
# classmates classmate NOUN NNS dobj xxxx True False
# . . PUNCT . punct . False False
# After after ADP IN prep Xxxxx True True
# appointing appoint VERB VBG pcomp xxxx True False
# herself -PRON- PRON PRP dative xxxx True True
# Edger Edger PROPN NNP compound Xxxxx True False
# Bergen Bergen PROPN NNP dobj Xxxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# Charlie Charlie PROPN NNP compound Xxxxx True False
# McCarthys McCarthys PROPN NNP pobj XxXxxxx True False
# and and CCONJ CC cc xxx True True
# Mortimer Mortimer PROPN NNP compound Xxxxx True False
# Snerds Snerds PROPN NNP conj Xxxxx True False
# in in ADP IN prep xx True True
# attendance attendance NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
#         SPACE _SP      False False
# bespectacled bespectacled PROPN NNP ROOT xxxx True False
# in in ADP IN prep xx True True
# granny granny ADJ JJ amod xxxx True False
# glasses glass NOUN NNS pobj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# awarding award VERB VBG advcl xxxx True False
# her -PRON- DET PRP$ poss xxx True True
# matronly matronly ADJ JJ amod xxxx True False
# wisdom wisdom NOUN NN dobj xxxx True False
# — — PUNCT : punct — False False
#     SPACE _SP    False False
# or or CCONJ CC cc xx True True
# at at ADP IN advmod xx True True
# least least ADJ JJS advmod xxxx True True
# John John PROPN NNP compound Xxxx True False
# Lennon Lennon PROPN NNP compound Xxxxx True False
# wisdom wisdom NOUN NN conj xxxx True False
# ) ) PUNCT -RRB- punct ) False False
# took take VERB VBD conj xxxx True False
# issue issue NOUN NN dobj xxxx True False
# with with ADP IN prep xxxx True True
# the the DET DT det xxx True True
# previous previous ADJ JJ amod xxxx True False
# speaker speaker NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Despite despite SCONJ IN prep Xxxxx True False
# becoming become VERB VBG pcomp xxxx True True
# the the DET DT det xxx True True
# first first ADJ JJ attr xxxx True True
#       SPACE _SP     False False
# to to PART TO aux xx True True
# win win VERB VB xcomp xxx True False
# election election NOUN NN dobj xxxx True False
# to to ADP IN prep xx True True
# a a DET DT det x True True
# seat seat NOUN NN pobj xxxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# U. U. PROPN NNP compound X. False False
# S. S. PROPN NNP compound X. False False
# Senate Senate PROPN NNP pobj Xxxxx True False
# since since SCONJ IN prep xxxx True True
# Reconstruction Reconstruction PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# Edward Edward PROPN NNP compound Xxxxx True False
# Brooke Brooke PROPN NNP nsubj Xxxxx True False
# came come VERB VBD ROOT xxxx True False
# in in ADP RP prt xx True True
# for for ADP IN prep xxx True True
# criticism criticism NOUN NN pobj xxxx True False
# for for ADP IN prep xxx True True
# calling call VERB VBG pcomp xxxx True False
# for for ADP IN prep xxx True True
# “ " PUNCT `` punct “ False False
# empathy empathy NOUN NN pobj xxxx True False
# ” " PUNCT '' punct ” False False
# for for ADP IN prep xxx True True
# the the DET DT det xxx True True
# goals goal NOUN NNS pobj xxxx True False
# of of ADP IN prep xx True True
# protestors protestor NOUN NNS pobj xxxx True False
# as as SCONJ IN mark xx True True
# he -PRON- PRON PRP nsubj xx True True
# criticized criticize VERB VBD advcl xxxx True False
# tactics tactic NOUN NNS dobj xxxx True False
# . . PUNCT . punct . False False
# Though though SCONJ IN mark Xxxxx True True
# Clinton Clinton PROPN NNP nsubj Xxxxx True False
# in in ADP IN prep xx True True
# her -PRON- DET PRP$ poss xxx True True
# senior senior ADJ JJ amod xxxx True False
# thesis thesis NOUN NN pobj xxxx True False
# on on ADP IN prep xx True True
# Saul Saul PROPN NNP compound Xxxx True False
# Alinsky Alinsky PROPN NNP pobj Xxxxx True False
# lamented lament VERB VBD ROOT xxxx True False
# “ " PUNCT `` punct “ False False
# Black Black PROPN NNP compound Xxxxx True False
# Power Power PROPN NNP compound Xxxxx True False
# demagogues demagogue NOUN NNS nsubj xxxx True False
# ” " PUNCT '' punct ” False False
# and and CCONJ CC cc xxx True True
# “ " PUNCT `` punct “ False False
# elitist elitist ADJ JJ amod xxxx True False
# arrogance arrogance NOUN NN conj xxxx True False
# and and CCONJ CC cc xxx True True
# repressive repressive ADJ JJ amod xxxx True False
# intolerance intolerance NOUN NN conj xxxx True False
# ” " PUNCT '' punct ” False False
# within within ADP IN prep xxxx True True
# the the DET DT det xxx True True
# New New PROPN NNP compound Xxx True False
# Left Left PROPN NNP pobj Xxxx True False
# , , PUNCT , punct , False False
# similar similar ADJ JJ amod xxxx True False
# words word NOUN NNS appos xxxx True False
# coming come VERB VBG acl xxxx True False
# out out SCONJ IN prep xxx True True
# of of ADP IN prep xx True True
# a a DET DT det x True True
# Republican Republican PROPN NNP pobj Xxxxx True False
# necessitated necessitate VERB VBD ccomp xxxx True False
# a a DET DT det x True True
# brief brief ADJ JJ amod xxxx True False
# rebuttal rebuttal NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
# “ " PUNCT `` punct “ False False
# Trust trust NOUN NN npadvmod Xxxxx True False
# , , PUNCT , punct , False False
# ” " PUNCT '' punct ” False False
# Rodham Rodham PROPN NNP nsubj Xxxxx True False
# ironically ironically ADV RB advmod xxxx True False
# observed observe VERB VBD ccomp xxxx True False
# in in ADP IN prep xx True True
# 1969 1969 NUM CD pobj dddd False False
# , , PUNCT , punct , False False
# “ " PUNCT `` punct “ False False
# this this DET DT nsubj xxxx True True
# is be AUX VBZ ccomp xx True True
# one one NUM CD nummod xxx True True
# word word NOUN NN attr xxxx True False
# that that SCONJ IN mark xxxx True True
# when when ADV WRB advmod xxxx True True
# I -PRON- PRON PRP nsubj X True True
# asked ask VERB VBD advcl xxxx True False
# the the DET DT det xxx True True
# class class NOUN NN dobj xxxx True False
# at at ADP IN prep xx True True
# our -PRON- DET PRP$ poss xxx True True
# rehearsal rehearsal NOUN NN pobj xxxx True False
# what what PRON WP attr xxxx True True
# it -PRON- PRON PRP nsubj xx True True
# was be AUX VBD ccomp xxx True True
# they -PRON- PRON PRP nsubj xxxx True True
# wanted want VERB VBD relcl xxxx True False
# me -PRON- PRON PRP nsubj xx True True
# to to PART TO aux xx True True
# say say VERB VB ccomp xxx True True
# for for ADP IN prep xxx True True
# them -PRON- PRON PRP pobj xxxx True True
# , , PUNCT , punct , False False
# everyone everyone PRON NN nsubj xxxx True True
# came come VERB VBD ROOT xxxx True False
# up up ADP RP prt xx True True
# to to ADP IN prep xx True True
# me -PRON- PRON PRP pobj xx True True
# and and CCONJ CC cc xxx True True
# said say VERB VBD conj xxxx True False
# ‘ ' PUNCT `` punct ‘ False False
# Talk talk NOUN NN xcomp Xxxx True False
# about about ADP IN prep xxxx True True
# trust trust NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# talk talk VERB VB conj xxxx True False
# about about ADP IN prep xxxx True True
# the the DET DT det xxx True True
# lack lack NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# trust trust NOUN NN pobj xxxx True False
# both both DET DT advmod xxxx True True
# for for ADP IN prep xxx True True
# us -PRON- PRON PRP pobj xx True True
# and and CCONJ CC cc xxx True True
# the the DET DT det xxx True True
# way way NOUN NN conj xxx True False
# we -PRON- PRON PRP nsubj xx True True
# feel feel VERB VBP relcl xxxx True False
# about about ADP IN prep xxxx True True
# others other NOUN NNS pobj xxxx True True
# . . PUNCT . punct . False False
# Talk talk VERB VB ROOT Xxxx True False
# about about ADP IN prep xxxx True True
# the the DET DT det xxx True True
# trust trust NOUN NN compound xxxx True False
# bust bust NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# ’ ' PUNCT '' punct ’ False False
# What what PRON WP dobj Xxxx True True
# can can VERB MD aux xxx True True
# you -PRON- PRON PRP nsubj xxx True True
# say say VERB VB ROOT xxx True True
# about about ADP IN prep xxxx True True
# it -PRON- PRON PRP pobj xx True True
# ? ? PUNCT . punct ? False False
# What what PRON WP dobj Xxxx True True
# can can VERB MD aux xxx True True
# you -PRON- PRON PRP nsubj xxx True True
# say say VERB VB ROOT xxx True True
# about about ADP IN prep xxxx True True
# a a DET DT det x True True
# feeling feeling NOUN NN pobj xxxx True False
# that that DET WDT nsubj xxxx True True
# permeates permeate VERB VBZ relcl xxxx True False
# a a DET DT det x True True
# generation generation NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True True
# that that SCONJ IN nsubj xxxx True True
# perhaps perhaps ADV RB advmod xxxx True True
# is be AUX VBZ auxpass xx True True
# not not PART RB neg xxx True True
# even even ADV RB advmod xxxx True True
# understood understand VERB VBN conj xxxx True False
# by by ADP IN agent xx True True
# those those DET DT pobj xxxx True True
# who who PRON WP nsubjpass xxx True True
# are be AUX VBP auxpass xxx True True
# distrusted distrust VERB VBN relcl xxxx True False
# ? ? PUNCT . punct ? False False
# ” " PUNCT '' punct ” False False
# The the DET DT det Xxx True True
# “ " PUNCT `` punct “ False False
# trust trust NOUN NN compound xxxx True False
# bust bust NOUN NN nsubj xxxx True False
# ” " PUNCT '' punct ” False False
# certainly certainly ADV RB advmod xxxx True False
# busted bust VERB VBD ROOT xxxx True False
# Clinton Clinton PROPN NNP dobj Xxxxx True False
# ’s ’s PART POS punct ’x False True
# 2016 2016 NUM CD nummod dddd False False
# plans plan NOUN NNS dobj xxxx True False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True True
# certainly certainly ADV RB advmod xxxx True False
# did do AUX VBD aux xxx True True
# not not PART RB neg xxx True True
# even even ADV RB advmod xxxx True True
# understand understand VERB VB ROOT xxxx True False
# that that SCONJ IN mark xxxx True True
# people people NOUN NNS nsubj xxxx True False
# distrusted distrust VERB VBD ccomp xxxx True False
# her -PRON- PRON PRP dobj xxx True True
# . . PUNCT . punct . False False
# After after ADP IN prep Xxxxx True True
# Whitewater Whitewater PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# Travelgate Travelgate PROPN NNP appos Xxxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
# vast vast ADJ JJ amod xxxx True False
#       SPACE _SP     False False
# conspiracy conspiracy NOUN NN conj xxxx True False
# , , PUNCT , punct , False False
# Benghazi Benghazi PROPN NNP conj Xxxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# the the DET DT det xxx True True
# missing miss VERB VBG amod xxxx True False
# emails email NOUN NNS conj xxxx True False
# , , PUNCT , punct , False False
# Clinton Clinton PROPN NNP nsubj Xxxxx True False
# found find VERB VBD ROOT xxxx True False
# herself -PRON- PRON PRP dative xxxx True True
# the the DET DT det xxx True True
# distrusted distrust VERB VBN amod xxxx True False
# voice voice NOUN NN dobj xxxx True False
# on on ADP IN prep xx True True
# Friday Friday PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
# There there PRON EX expl Xxxxx True True
# was be AUX VBD ROOT xxx True True
# a a DET DT det x True True
# load load NOUN NN attr xxxx True False
# of of ADP IN prep xx True True
# compromising compromise VERB VBG pcomp xxxx True False
# on on ADP IN prep xx True True
# the the DET DT det xxx True True
# road road NOUN NN pobj xxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# broadening broadening NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# her -PRON- DET PRP$ poss xxx True True
# political political ADJ JJ amod xxxx True False
# horizons horizon NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# And and CCONJ CC cc Xxx True True
# distrust distrust VERB VB npadvmod xxxx True False
# from from ADP IN prep xxxx True True
# the the DET DT det xxx True True
# American american ADJ JJ amod Xxxxx True False
# people people NOUN NNS pobj xxxx True False
# — — PUNCT : punct — False False
#     SPACE _SP    False False
# Trump Trump PROPN NNP nsubj Xxxxx True False
# edged edge VERB VBD ccomp xxxx True False
# her -PRON- DET PRP$ poss xxx True True
# 48 48 NUM CD nummod dd False False
# percent percent NOUN NN dobj xxxx True False
# to to ADP IN prep xx True True
# 38 38 NUM CD nummod dd False False
# percent percent NOUN NN pobj xxxx True False
# on on ADP IN prep xx True True
# the the DET DT det xxx True True
# question question NOUN NN pobj xxxx True False
# immediately immediately ADV RB advmod xxxx True False
# prior prior ADV RB advmod xxxx True False
# to to ADP IN prep xx True True
# November November PROPN NNP pobj Xxxxx True False
# ’s ’s PART POS punct ’x False True
# election election NOUN NN npadvmod xxxx True False
# — — PUNCT : punct — False False
#     SPACE _SP    False False
# stood stand VERB VBD ROOT xxxx True False
# as as SCONJ IN prep xx True True
# a a DET DT det x True True
# major major ADJ JJ amod xxxx True False
# reason reason NOUN NN pobj xxxx True False
# for for ADP IN prep xxx True True
# the the DET DT det xxx True True
# closing closing NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# those those DET DT det xxxx True True
# horizons horizon NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# Clinton Clinton PROPN NNP nsubj Xxxxx True False
# described describe VERB VBD ROOT xxxx True False
# her -PRON- DET PRP$ poss xxx True True
# vanquisher vanquisher NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True True
# his -PRON- DET PRP$ poss xxx True True
# supporters supporter NOUN NNS conj xxxx True False
# as as SCONJ IN prep xx True True
# embracing embrace VERB VBG pcomp xxxx True False
# a a DET DT det x True True
# “ " PUNCT `` punct “ False False
# lie lie NOUN NN dobj xxx True False
# , , PUNCT , punct , False False
# ” " PUNCT '' punct ” False False
# a a DET DT det x True True
# “ " PUNCT `` punct “ False False
# con con NOUN NN appos xxx True False
# , , PUNCT , punct , False False
# ” " PUNCT '' punct ” False False
# “ " PUNCT `` punct “ False False
# alternative alternative ADJ JJ amod xxxx True False
# facts fact NOUN NNS appos xxxx True False
# , , PUNCT , punct , False False
# ” " PUNCT '' punct ” False False
# and and CCONJ CC cc xxx True True
# “ " PUNCT `` punct “ False False
# a a DET DT det x True True
#       SPACE _SP     False False
# assault assault NOUN NN conj xxxx True False
# on on ADP IN prep xx True True
# truth truth NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# reason reason NOUN NN conj xxxx True False
# . . PUNCT . punct . False False
# ” " PUNCT '' punct ” False False
# She -PRON- PRON PRP nsubj Xxx True True
# failed fail VERB VBD ROOT xxxx True False
# to to PART TO aux xx True True
# explain explain VERB VB xcomp xxxx True False
# why why ADV WRB advmod xxx True True
# the the DET DT det xxx True True
# American american ADJ JJ amod Xxxxx True False
# people people NOUN NNS nsubj xxxx True False
# chose choose VERB VBD ccomp xxxx True False
# his -PRON- DET PRP$ poss xxx True True
# lies lie NOUN NNS dobj xxxx True False
# over over ADP IN prep xxxx True True
# her -PRON- DET PRP$ poss xxx True True
# truth truth NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# “ " PUNCT `` punct “ False False
# As as SCONJ IN mark Xx True True
# the the DET DT det xxx True True
# history history NOUN NN nsubj xxxx True False
# majors major NOUN NNS nsubj xxxx True False
# among among ADP IN prep xxxx True True
# you -PRON- PRON PRP pobj xxx True True
# here here ADV RB advmod xxxx True True
# today today NOUN NN npadvmod xxxx True False
# know know VERB VBP ccomp xxxx True False
# all all ADV RB advmod xxx True True
# too too ADV RB advmod xxx True True
# well well ADV RB advmod xxxx True True
# , , PUNCT , punct , False False
# when when ADV WRB advmod xxxx True True
# people people NOUN NNS nsubj xxxx True False
# in in ADP IN prep xx True True
# power power NOUN NN pobj xxxx True False
# invent invent VERB VBP advcl xxxx True False
# their -PRON- DET PRP$ poss xxxx True True
# own own ADJ JJ amod xxx True True
# facts fact NOUN NNS dobj xxxx True False
# and and CCONJ CC cc xxx True True
# attack attack VERB VB conj xxxx True False
# those those DET DT dobj xxxx True True
# who who PRON WP nsubj xxx True True
# question question VERB VBP relcl xxxx True False
# them -PRON- PRON PRP dobj xxxx True True
# , , PUNCT , punct , False False
# it -PRON- PRON PRP nsubj xx True True
# can can VERB MD aux xxx True True
# mark mark VERB VB ccomp xxxx True False
# the the DET DT det xxx True True
# beginning beginning NOUN NN dobj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# end end NOUN NN pobj xxx True False
# of of ADP IN prep xx True True
# a a DET DT det x True True
# free free ADJ JJ amod xxxx True False
# society society NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# ” " PUNCT '' punct ” False False
# she -PRON- PRON PRP nsubj xxx True True
# offered offer VERB VBD ROOT xxxx True False
# . . PUNCT . punct . False False
# “ " PUNCT `` punct “ False False
# That that DET DT nsubj Xxxx True True
# is be AUX VBZ ROOT xx True True
# not not PART RB neg xxx True True
# hyperbole hyperbole NOUN NN acomp xxxx True False
# . . PUNCT . punct . False False
# ” " PUNCT '' punct ” False False
# Like like SCONJ IN mark Xxxx True False
# so so ADV RB advmod xx True True
# many many ADJ JJ amod xxxx True True
# people people NOUN NNS nsubj xxxx True False
# to to PART TO aux xx True True
# emerge emerge VERB VB advcl xxxx True False
# from from ADP IN prep xxxx True True
# the the DET DT det xxx True True
# 1960s 1960 NOUN NNS pobj ddddx False False
# , , PUNCT , punct , False False
# Hillary Hillary PROPN NNP compound Xxxxx True False
# Clinton Clinton PROPN NNP nsubj Xxxxx True False
# embarked embark VERB VBD ROOT xxxx True False
# upon upon SCONJ IN prep xxxx True True
# a a DET DT det x True True
# long long ADJ JJ amod xxxx True False
# , , PUNCT , punct , False False
# strange strange ADJ JJ amod xxxx True False
# trip trip NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# From from ADP IN prep Xxxx True True
# high high ADJ JJ amod xxxx True False
# school school NOUN NN compound xxxx True False
# Goldwater Goldwater PROPN NNP compound Xxxxx True False
# Girl Girl PROPN NNP nmod Xxxx True False
# and and CCONJ CC cc xxx True True
# Wellesley Wellesley PROPN NNP compound Xxxxx True False
# College College PROPN NNP conj Xxxxx True False
# Republican republican ADJ JJ amod Xxxxx True False
# president president NOUN NN pobj xxxx True False
# to to ADP IN prep xx True True
# Democratic democratic ADJ JJ amod Xxxxx True False
# politician politician NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# Clinton Clinton PROPN NNP nsubj Xxxxx True False
# drank drink VERB VBD ROOT xxxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# times time NOUN NNS pobj xxxx True False
# and and CCONJ CC cc xxx True True
# the the DET DT det xxx True True
# place place NOUN NN conj xxxx True False
# that that DET WDT nsubj xxxx True True
# gave give VERB VBD relcl xxxx True False
# her -PRON- PRON PRP dative xxx True True
# a a DET DT det x True True
# degree degree NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
# More more ADV RBR advmod Xxxx True True
# significantly significantly ADV RB advmod xxxx True False
# , , PUNCT , punct , False False
# she -PRON- PRON PRP nsubj xxx True True
# went go VERB VBD ROOT xxxx True False
# from from ADP IN prep xxxx True True
# idealist idealist NOUN NN pobj xxxx True False
# to to PART TO prep xx True True
# cynic cynic VERB VB pobj xxxx True False
# , , PUNCT , punct , False False
# as as SCONJ IN prep xx True True
# a a DET DT det x True True
# comparison comparison NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# her -PRON- DET PRP$ poss xxx True True
# two two NUM CD nummod xxx True True
# Wellesley Wellesley PROPN NNP compound Xxxxx True False
# commencement commencement NOUN NN compound xxxx True False
# addresses address NOUN NNS compound xxxx True False
# show show VERB VBP pobj xxxx True True
# . . PUNCT . punct . False False
# Way way ADV RB advmod Xxx True False
# back back ADV RB advmod xxxx True True
# when when ADV WRB advmod xxxx True True
# , , PUNCT , punct , False False
# she -PRON- PRON PRP nsubj xxx True True
# lamented lament VERB VBD ROOT xxxx True False
# that that SCONJ IN mark xxxx True True
# “ " PUNCT `` punct “ False False
# for for ADP IN prep xxx True True
# too too ADV RB advmod xxx True True
# long long ADV RB pcomp xxxx True False
# our -PRON- DET PRP$ poss xxx True True
# leaders leader NOUN NNS nsubj xxxx True False
# have have AUX VBP aux xxxx True True
# viewed view VERB VBN ccomp xxxx True False
# politics politic NOUN NNS dobj xxxx True False
# as as SCONJ IN prep xx True True
# the the DET DT det xxx True True
# art art NOUN NN pobj xxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# possible possible ADJ JJ pobj xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# the the DET DT det xxx True True
# challenge challenge NOUN NN nsubj xxxx True False
# now now ADV RB advmod xxx True True
# is be AUX VBZ conj xx True True
# to to PART TO aux xx True True
# practice practice VERB VB xcomp xxxx True False
# politics politic NOUN NNS dobj xxxx True False
# as as SCONJ IN prep xx True True
# the the DET DT det xxx True True
# art art NOUN NN pobj xxx True False
# of of ADP IN prep xx True True
# making make VERB VBG pcomp xxxx True False
# what what PRON WP nsubj xxxx True True
# appears appear VERB VBZ ccomp xxxx True False
# to to PART TO aux xx True True
# be be AUX VB xcomp xx True True
# impossible impossible ADJ JJ advmod xxxx True False
# possible possible ADJ JJ acomp xxxx True False
# . . PUNCT . punct . False False
# ” " PUNCT '' punct ” False False
# Now now ADV RB advmod Xxx True True
# , , PUNCT , punct , False False
# as as SCONJ IN prep xx True True
# the the DET DT det xxx True True
# big big ADJ JJ amod xxx True False
# woman woman NOUN NN pobj xxxx True False
# on on ADP IN prep xx True True
# campus campus NOUN NN pobj xxxx True False
# but but CCONJ CC cc xxx True True
# the the DET DT det xxx True True
# odd odd ADJ JJ amod xxx True False
# woman woman NOUN NN conj xxxx True False
# out out SCONJ IN prep xxx True True
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# White White PROPN NNP compound Xxxxx True False
# House House PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# she -PRON- PRON PRP nsubj xxx True True
# wonders wonder VERB VBZ ROOT xxxx True False
# how how ADV WRB advmod xxx True True
# her -PRON- DET PRP$ poss xxx True True
# current current ADJ JJ amod xxxx True False
# station station NOUN NN nsubj xxxx True False
# is be AUX VBZ ccomp xx True True
# even even ADV RB advmod xxxx True True
# possible possible ADJ JJ acomp xxxx True False
# . . PUNCT . punct . False False
# “ " PUNCT `` punct “ False False
# Why why ADV WRB advmod Xxx True True
# are be AUX VBP ROOT xxx True True
# n’t not PART RB neg x’x False True
# I -PRON- PRON PRP nsubj X True True
# 50 50 NUM CD nummod dd False False
# points point NOUN NNS npadvmod xxxx True False
# ahead ahead ADV RB advmod xxxx True False
# ? ? PUNCT . punct ? False False
# ” " PUNCT '' punct ” False False
# she -PRON- PRON PRP nsubj xxx True True
# asked ask VERB VBD ROOT xxxx True False
# in in ADP IN prep xx True True
# September September PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
# In in ADP IN prep Xx True True
# May May PROPN NNP pobj Xxx True True
# she -PRON- PRON PRP nsubj xxx True True
# asks ask VERB VBZ ROOT xxxx True False
# why why ADV WRB advmod xxx True True
# she -PRON- PRON PRP nsubj xxx True True
# is be AUX VBZ ccomp xx True True
# n’t not PART RB neg x’x False True
# president president NOUN NN attr xxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True True
# woman woman NOUN NN nsubj xxxx True False
# famously famously ADV RB advmod xxxx True False
# dubbed dub VERB VBD ROOT xxxx True False
# a a DET DT det x True True
# “ " PUNCT `` punct “ False False
# congenital congenital ADJ JJ amod xxxx True False
# liar liar NOUN NN oprd xxxx True False
# ” " PUNCT '' punct ” False False
# by by ADP IN prep xx True True
# Bill Bill PROPN NNP compound Xxxx True False
# Safire Safire PROPN NNP pobj Xxxxx True False
# concludes conclude VERB VBZ conj xxxx True False
# that that SCONJ IN mark xxxx True True
# lies lie NOUN NNS nsubj xxxx True False
# did do AUX VBD ccomp xxx True True
# her -PRON- PRON PRP dobj xxx True True
# in in ADP IN prep xx True True
# — — PUNCT : punct — False False
#     SPACE _SP    False False
# theirs -PRON- PRON PRP npadvmod xxxx True False
# , , PUNCT , punct , False False
# mind mind VERB VB conj xxxx True False
# you -PRON- PRON PRP dobj xxx True True
# , , PUNCT , punct , False False
# not not PART RB neg xxx True True
# hers her NOUN NNS appos xxxx True True
# . . PUNCT . punct . False False
# Getting get VERB VBG auxpass Xxxxx True False
# stood stand VERB VBD ROOT xxxx True False
# up up ADP RP prt xx True True
# on on ADP IN prep xx True True
# Election Election PROPN NNP compound Xxxxx True False
# Day Day PROPN NNP pobj Xxx True False
# , , PUNCT , punct , False False
# like like SCONJ IN prep xxxx True False
# finding find VERB VBG pcomp xxxx True False
# yourself -PRON- PRON PRP dobj xxxx True True
# the the DET DT det xxx True True
# jilted jilted ADJ JJ amod xxxx True False
# bride bride NOUN NN dobj xxxx True False
# on on ADP IN prep xx True True
# your -PRON- DET PRP$ poss xxxx True True
# wedding wedding NOUN NN compound xxxx True False
# day day NOUN NN pobj xxx True False
# , , PUNCT , punct , False False
# inspires inspire NOUN NNS dep xxxx True False
# dangerous dangerous ADJ JJ amod xxxx True False
# delusions delusion NOUN NNS dobj xxxx True False
# . . PUNCT . punct . False False

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Hillary Clinton 125 140 PERSON
# leafy 176 181 GPE
# Wellesley 191 200 GPE
# Massachusetts 202 215 GPE
# Havisham 328 336 PERSON
# Hillary Rodham 403 417 PERSON
# 48 years ago 439 451 DATE
# first 461 466 ORDINAL
# Wellesley 479 488 GPE
# 1969 563 567 DATE
# Democratic 691 701 NORP
# 2016 715 719 DATE
# Seven 761 766 CARDINAL
# Adams 810 815 PERSON
# today 858 863 DATE
# 400 884 887 CARDINAL
# Rodham 901 907 PERSON
# Edger Bergen 954 966 PERSON
# Charlie McCarthys 974 991 PERSON
# Mortimer Snerds 996 1011 PERSON
# John Lennon 1110 1121 PERSON
# Edward Brooke 1265 1278 PERSON
# Clinton 1388 1395 PERSON
# Saul Alinsky 1420 1432 PERSON
# Black Power 1443 1454 WORK_OF_ART
# the New Left 1525 1537 LOC
# Republican 1569 1579 NORP
# Rodham 1620 1626 PERSON
# 1969 1650 1654 DATE
# one 1665 1668 CARDINAL
# Clinton 2109 2116 PERSON
# 2016 2119 2123 DATE
# Whitewater 2203 2213 ORG
# Travelgate 2215 2225 ORG
# Benghazi 2250 2258 PERSON
# Clinton 2284 2291 PERSON
# Friday 2330 2336 DATE
# American 2450 2458 NORP
# Trump 2469 2474 PERSON
# 48 percent 2485 2495 PERCENT
# 38 percent 2499 2509 PERCENT
# November 2547 2555 DATE
# Clinton 2629 2636 PERSON
# American 2803 2811 NORP
# today 2888 2893 DATE
# the 1960s 3124 3133 DATE
# Hillary Clinton 3135 3150 PERSON
# Goldwater Girl 3204 3218 PERSON
# Wellesley College 3223 3240 ORG
# Republican 3241 3251 NORP
# Democratic 3265 3275 NORP
# Clinton 3288 3295 PERSON
# two 3429 3432 CARDINAL
# Wellesley 3433 3442 GPE
# the White House 3746 3761 ORG
# 50 3831 3833 CARDINAL
# September 3862 3871 DATE
# May 3876 3879 DATE
# Bill Safire 3963 3974 PERSON
# Election Day 4057 4069 DATE
# wedding day 4118 4129 DATE

# %%
from spacy.lang.en import English

# %%
from spacy import displacy

displacy.serve(doc, style="ent")
# Out:
# C:\Users\mari_\AppData\Local\Continuum\anaconda3\envs\data\lib\runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">Ever get the feeling your life circles the roundabout rather than heads in a straight line toward the intended destination? [
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hillary Clinton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  remains the big woman on campus in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     leafy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , liberal
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wellesley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Massachusetts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . Everywhere else votes her most likely to don her inauguration dress for the remainder of her days the way Miss
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Havisham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  forever wore that wedding dress.  Speaking of Great Expectations,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hillary Rodham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  overflowed with them
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     48 years ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  when she
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  addressed a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wellesley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  graduating class. The president of the college informed those gathered in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1969
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that the students needed “no debate so far as I could ascertain as to who their spokesman was to be” (kind of the like the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Democratic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  primaries in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2016
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  minus the   terms unknown then even at a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seven
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Sisters school). “I am very glad that Miss
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adams
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  made it clear that what I am speaking for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  is all of us —  the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     400
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of us,” Miss
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rodham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  told her classmates. After appointing herself
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Edger Bergen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Charlie McCarthys
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mortimer Snerds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in attendance, the    bespectacled in granny glasses (awarding her matronly wisdom —  or at least
# <mark class="entit
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.
